# %%
from planet import api
import json
from datetime import datetime, timedelta

# %%
# query setup
client = api.ClientV1(api_key='API_KEY_HERE')

aoi = {
    "type": "Polygon",
    "coordinates": [
        [
            [
              -123.11553955078125,
              37.63815995799935
            ],
            [
              -122.2723388671875,
              37.63815995799935
            ],
            [
              -122.2723388671875,
              38.25867146839721
            ],
            [
              -123.11553955078125,
              38.25867146839721
            ],
            [
              -123.11553955078125,
              37.63815995799935
            ]
        ]
    ]
}

end_date = datetime.utcnow()
start_date = end_date - timedelta(days=90)

# %%
# build query
aoi = api.filters.geom_filter(aoi)
cloud = api.filters.range_filter('cloud_cover', gte=0.50, lte=0.99)
date = api.filters.date_range('acquired', gte=start_date, lte=end_date)
query = api.filters.and_filter(aoi, cloud, date)
query
# Out:
# {'type': 'AndFilter',
#  'config': ({'field_name': 'geometry',
#    'type': 'GeometryFilter',
#    'config': {'type': 'Polygon',
#     'coordinates': [[[-123.11553955078125, 37.63815995799935],
#       [-122.2723388671875, 37.63815995799935],
#       [-122.2723388671875, 38.25867146839721],
#       [-123.11553955078125, 38.25867146839721],
#       [-123.11553955078125, 37.63815995799935]]]}},
#   {'field_name': 'cloud_cover',
#    'type': 'RangeFilter',
#    'config': {'gte': 0.5, 'lte': 0.99}},
#   {'field_name': 'acquired',
#    'type': 'DateRangeFilter',
#    'config': {'gte': '2019-05-24T03:14:37.955033Z',
#     'lte': '2019-08-22T03:14:37.955033Z'}})}

# %%
# build request query and write it out to a file
test_request = api.filters.build_search_request(query, ['PSScene4Band'])


with open('test_request.json', 'w') as request_file:
    request_file.write(json.dumps(test_request, indent=2))
    
test_request

# %%
# execute query
test_results = client.quick_search(test_request)
test_results

# %%
help(test_results)
# Out:
# Help on Items in module planet.api.models object:
#
# class Items(Features)
#  |  A Body that contains JSON
#  |
#  |  Method resolution order:
#  |      Items
#  |      Features
#  |      Paged
#  |      JSON
#  |      Body
#  |      builtins.object
#  |
#  |  Methods inherited from Paged:
#  |
#  |  items_iter(self, limit)
#  |      Get an iterator of the 'items' in each page. Instead of a feature
#  |      collection from each page, the iterator yields the features.
#  |
#  |      :param int limit: The number of 'items' to limit to.
#  |      :return: iter of items in page
#  |
#  |  iter(self, pages=None)
#  |      Get an iterator of pages.
#  |
#  |      :param int pages: optional limit to number of pages
#  |      :return: iter of this and subsequent pages
#  |
#  |  json_encode(self, out, limit=None, sort_keys=False, indent=None)
#  |      Encode the results of this paged response as JSON writing to the
#  |      provided file-like `out` object. This function will iteratively read
#  |      as many pages as present, streaming the contents out as JSON.
#  |
#  |      :param file-like out: an object with a `write` function
#  |      :param int limit: optional maximum number of items to write
#  |      :param bool sort_keys: if True, output keys sorted, default is False
#  |      :param bool indent: if True, indent output, default is False
#  |
#  |  next(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from Paged:
#  |
#  |  ITEM_KEY = 'features'
#  |
#  |  LINKS_KEY = '_links'
#  |
#  |  NEXT_KEY = '_next'
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from JSON:
#  |
#  |  get(self)
#  |      Get the response as a JSON dict
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Body:
#  |
#  |  __init__(self, request, http_response, dispatcher)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |
#  |  __len__(self)
#  |
#  |  get_raw(self)
#  |      Get the decoded text content from the response
#  |
#  |  last_modified(self)
#  |      Read the last-modified header as a datetime, if present.
#  |
#  |  write(self, file=None, callback=None)
#  |      Write the contents of the body to the optionally provided file and
#  |      providing progress to the optional callback. The callback will be
#  |      invoked 3 different ways:
#  |
#  |      * First as ``callback(start=self)``
#  |      * For each chunk of data written as
#  |        ``callback(wrote=chunk_size_in_bytes, total=all_byte_cnt)``
#  |      * Upon completion as ``callback(finish=self)``
#  |
#  |      :param file: file name or file-like object
#  |      :param callback: optional progress callback
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Body:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  name
#  |      The name of this resource. The default is to use the
#  |      content-disposition header value from the response.

# %%
# write and print query results
# can use the built-in method to write a compact file
# test_results.write(file = 'test_results.json')
with open ('test_results.json', 'w') as results_file:
    results_file.write(json.dumps(test_results.get(), indent=2))

json_results = test_results.get()
print(json.dumps(json_results, indent=2))
# Out:
# {
#   "_links": {
#     "_first": "https://api.planet.com/data/v1/searches/f9172c40a05f41ecbfde379edfa191d5/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D",
#     "_next": "https://api.planet.com/data/v1/searches/f9172c40a05f41ecbfde379edfa191d5/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6ICIyMDE5LTA3LTMwVDAwOjIxOjMyLjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMTkwNzI5XzE3MjYzNF8wZjNjIiwgInNvcnRfZGVzYyI6IHRydWV9",
#     "_self": "https://api.planet.com/data/v1/searches/f9172c40a05f41ecbfde379edfa191d5/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D"
#   },
#   "features": [
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_172423_104b",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_172423_104b/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20190820_172423_104b/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.udm2:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_udm2:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -122.52812616842282,
#               37.65405656812706
#             ],
#             [
#               -122.78362388101002,
#               37.617425850016005
#             ],
#             [
#               -122.79852070176044,
#               37.68718953237288
#             ],
#             [
#               -122.54280548437528,
#               37.72390184392511
#             ],
#             [
#               -122.53942038079931,
#               37.7078209266535
#             ],
#             [
#               -122.53944372806347,
#               37.70781763985041
#             ],
#             [
#               -122.52812616842282,
#               37.65405656812706
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20190820_172423_104b",
#       "properties": {
#         "acquired": "2019-08-20T17:24:23.117741Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 44,
#         "clear_percent": 55,
#         "cloud_cover": 0.91,
#         "cloud_percent": 23,
#         "columns": 7954,
#         "epsg_code": 32610,
#         "ground_control": false,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "light_haze_percent": 0,
#         "origin_x": 517764,
#         "origin_y": 4175283,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2019-08-21T02:41:54Z",
#         "quality_category": "test",
#         "rows": 3964,
#         "satellite_id": "104b",
#         "shadow_percent": 0,
#         "snow_ice_percent": 22,
#         "strip_id": "2614876",
#         "sun_azimuth": 111.9,
#         "sun_elevation": 44.3,
#         "updated": "2019-08-21T04:48:28Z",
#         "view_angle": 4.9,
#         "visible_confidence_percent": 47,
#         "visible_percent": 77
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_172207_1048",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_172207_1048/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20190820_172207_1048/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.udm2:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_udm2:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -123.18677378949687,
#               38.16758766568425
#             ],
#             [
#               -123.19911911596728,
#               38.21422960272084
#             ],
#             [
#               -122.93689593585964,
#               38.25761998657528
#             ],
#             [
#               -122.9343906637418,
#               38.248098611633544
#             ],
#             [
#               -122.93401966116942,
#               38.24816053970741
#             ],
#             [
#               -122.92646152779425,
#               38.220264991669154
#             ],
#             [
#               -122.91885652123142,
#               38.19111699540907
#             ],
#             [
#               -123.18124416270739,
#               38.14728276556441
#             ],
#             [
#               -123.18677378949687,
#               38.16758766568425
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20190820_172207_1048",
#       "properties": {
#         "acquired": "2019-08-20T17:22:07.440356Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 29,
#         "clear_percent": 19,
#         "cloud_cover": 0.98,
#         "cloud_percent": 77,
#         "columns": 8180,
#         "epsg_code": 32610,
#         "ground_control": false,
#         "gsd": 3.6,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "light_haze_percent": 3,
#         "origin_x": 482568,
#         "origin_y": 4234404,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2019-08-21T02:41:38Z",
#         "quality_category": "test",
#         "rows": 4078,
#         "satellite_id": "1048",
#         "shadow_percent": 1,
#         "snow_ice_percent": 0,
#         "strip_id": "2614859",
#         "sun_azimuth": 112.4,
#         "sun_elevation": 44,
#         "updated": "2019-08-21T04:54:05Z",
#         "view_angle": 4.9,
#         "visible_confidence_percent": 34,
#         "visible_percent": 23
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183804_1001",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183804_1001/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183804_1001/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.udm2:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_udm2:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -123.25928497616542,
#               38.14333207522026
#             ],
#             [
#               -123.25889334131897,
#               38.144703056725746
#             ],
#             [
#               -122.9715022406446,
#               38.09431067854818
#             ],
#             [
#               -122.97353410832667,
#               38.08704553037645
#             ],
#             [
#               -122.97447418568791,
#               38.083787208560906
#             ],
#             [
#               -122.97444672630562,
#               38.083782372593284
#             ],
#             [
#               -122.98653425634203,
#               38.040562187775535
#             ],
#             [
#               -122.99212881506654,
#               38.02113621978011
#             ],
#             [
#               -123.27932033310445,
#               38.07176229159801
#             ],
#             [
#               -123.2653173735355,
#               38.12221468665486
#             ],
#             [
#               -123.26183771370916,
#               38.13439580207549
#             ],
#             [
#               -123.26176785918679,
#               38.134383499751834
#             ],
#             [
#               -123.25928497616542,
#               38.14333207522026
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20190820_183804_1001",
#       "properties": {
#         "acquired": "2019-08-20T18:38:04.005117Z",
#         "anomalous_pixels": 0.18,
#         "clear_confidence_percent": 65,
#         "clear_percent": 0,
#         "cloud_cover": 0.98,
#         "cloud_percent": 100,
#         "columns": 9000,
#         "epsg_code": 32610,
#         "ground_control": false,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "light_haze_percent": 0,
#         "origin_x": 475500,
#         "origin_y": 4221903,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2019-08-21T02:39:05Z",
#         "quality_category": "test",
#         "rows": 4581,
#         "satellite_id": "1001",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "2614998",
#         "sun_azimuth": 132.8,
#         "sun_elevation": 56.1,
#         "updated": "2019-08-21T04:29:30Z",
#         "view_angle": 3,
#         "visible_confidence_percent": 58,
#         "visible_percent": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_185220_52_1057",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_185220_52_1057/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20190820_185220_52_1057/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.udm2:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_udm2:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -123.03097560694144,
#               37.95707845759536
#             ],
#             [
#               -123.07174212220988,
#               37.811204109832765
#             ],
#             [
#               -122.79508179176901,
#               37.761728070081084
#             ],
#             [
#               -122.75315637203434,
#               37.90800402975466
#             ],
#             [
#               -123.03097560694144,
#               37.95707845759536
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20190820_185220_52_1057",
#       "properties": {
#         "acquired": "2019-08-20T18:52:20.521265Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 37,
#         "clear_percent": 0,
#         "cloud_cover": 0.5,
#         "cloud_percent": 100,
#         "columns": 9339,
#         "epsg_code": 32610,
#         "ground_control": false,
#         "gsd": 3.8,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2.SD",
#         "item_type": "PSScene4Band",
#         "light_haze_percent": 0,
#         "origin_x": 493683,
#         "origin_y": 4201056,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2019-08-21T00:25:17Z",
#         "quality_category": "test",
#         "rows": 7220,
#         "satellite_id": "1057",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "2615355",
#         "sun_azimuth": 138.1,
#         "sun_elevation": 58.3,
#         "updated": "2019-08-21T04:47:30Z",
#         "view_angle": 4,
#         "visible_confidence_percent": 60,
#         "visible_percent": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183513_1003",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183513_1003/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183513_1003/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.udm2:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_udm2:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -122.68935180185285,
#               37.6541370533458
#             ],
#             [
#               -122.67515526294284,
#               37.70474167463338
#             ],
#             [
#               -122.38940824186191,
#               37.65494120342104
#             ],
#             [
#               -122.39252807860036,
#               37.64394793525268
#             ],
#             [
#               -122.39243632034585,
#               37.64393187440334
#             ],
#             [
#               -122.3978099094359,
#               37.62460305117776
#             ],
#             [
#               -122.41026663136432,
#               37.58126650680369
#             ],
#             [
#               -122.69562585785276,
#               37.631147423969374
#             ],
#             [
#               -122.68935180185285,
#               37.6541370533458
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20190820_183513_1003",
#       "properties": {
#         "acquired": "2019-08-20T18:35:13.806173Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 27,
#         "clear_percent": 0,
#         "cloud_cover": 0.83,
#         "cloud_percent": 100,
#         "columns": 9002,
#         "epsg_code": 32610,
#         "ground_control": false,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "light_haze_percent": 0,
#         "origin_x": 526854,
#         "origin_y": 4173108,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2019-08-21T00:19:19Z",
#         "quality_category": "test",
#         "rows": 4530,
#         "satellite_id": "1003",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "2614990",
#         "sun_azimuth": 132.1,
#         "sun_elevation": 56.4,
#         "updated": "2019-08-21T04:28:05Z",
#         "view_angle": 3,
#         "visible_confidence_percent": 52,
#         "visible_percent": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183512_1003",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183512_1003/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183512_1003/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.udm2:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_udm2:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -122.66994706672784,
#               37.72438614139544
#             ],
#             [
#               -122.65970623951549,
#               37.76081144191625
#             ],
#             [
#               -122.65930866272889,
#               37.76074184791567
#             ],
#             [
#               -122.65635718726001,
#               37.77160648463528
#             ],
#             [
#               -122.37064553743564,
#               37.72178140614279
#             ],
#             [
#               -122.37961369621465,
#               37.68945392825706
#             ],
#             [
#               -122.39135358243487,
#               37.648086469539074
#             ],
#             [
#               -122.67712851256792,
#               37.698096816170825
#             ],
#             [
#               -122.66994706672784,
#               37.72438614139544
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20190820_183512_1003",
#       "properties": {
#         "acquired": "2019-08-20T18:35:12.745538Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 49,
#         "clear_percent": 1,
#         "cloud_cover": 0.9,
#         "cloud_percent": 98,
#         "columns": 9001,
#         "epsg_code": 32610,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "light_haze_percent": 0,
#         "origin_x": 528462,
#         "origin_y": 4180533,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2019-08-21T00:19:19Z",
#         "quality_category": "standard",
#         "rows": 4530,
#         "satellite_id": "1003",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "2614990",
#         "sun_azimuth": 132.2,
#         "sun_elevation": 56.3,
#         "updated": "2019-08-21T04:28:49Z",
#         "view_angle": 3,
#         "visible_confidence_percent": 55,
#         "visible_percent": 2
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183511_1003",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183511_1003/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183511_1003/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.udm2:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_udm2:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -122.63814223274431,
#               37.83842980450368
#             ],
#             [
#               -122.35201885819947,
#               37.78853844990521
#             ],
#             [
#               -122.37241694059406,
#               37.7148633330121
#             ],
#             [
#               -122.65818569320005,
#               37.764875595970366
#             ],
#             [
#               -122.64108223469539,
#               37.827834907427246
#             ],
#             [
#               -122.64102269121507,
#               37.82782449246243
#             ],
#             [
#               -122.63814223274431,
#               37.83842980450368
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20190820_183511_1003",
#       "properties": {
#         "acquired": "2019-08-20T18:35:11.684379Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 66,
#         "clear_percent": 32,
#         "cloud_cover": 0.57,
#         "cloud_percent": 66,
#         "columns": 8984,
#         "epsg_code": 32610,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "light_haze_percent": 1,
#         "origin_x": 530103,
#         "origin_y": 4187952,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2019-08-21T00:19:19Z",
#         "quality_category": "standard",
#         "rows": 4530,
#         "satellite_id": "1003",
#         "shadow_percent": 1,
#         "snow_ice_percent": 0,
#         "strip_id": "2614990",
#         "sun_azimuth": 132.3,
#         "sun_elevation": 56.3,
#         "updated": "2019-08-21T04:28:42Z",
#         "view_angle": 3,
#         "visible_confidence_percent": 50,
#         "visible_percent": 34
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183415_101f",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183415_101f/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183415_101f/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.udm2:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_udm2:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -122.3848757803928,
#               37.63038095252451
#             ],
#             [
#               -122.36625384029266,
#               37.69691083819944
#             ],
#             [
#               -122.0817356636184,
#               37.64747719223145
#             ],
#             [
#               -122.08482967255426,
#               37.63648081928477
#             ],
#             [
#               -122.08412345512585,
#               37.63635758355514
#             ],
#             [
#               -122.10170927148671,
#               37.57393386533371
#             ],
#             [
#               -122.38668131179132,
#               37.62372985845567
#             ],
#             [
#               -122.3848757803928,
#               37.63038095252451
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20190820_183415_101f",
#       "properties": {
#         "acquired": "2019-08-20T18:34:15.737563Z",
#         "anomalous_pixels": 0.4,
#         "clear_confidence_percent": 40,
#         "clear_percent": 2,
#         "cloud_cover": 0.95,
#         "cloud_percent": 96,
#         "columns": 8962,
#         "epsg_code": 32610,
#         "ground_control": false,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "light_haze_percent": 0,
#         "origin_x": 554121,
#         "origin_y": 4172379,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2019-08-21T00:10:06Z",
#         "quality_category": "test",
#         "rows": 4486,
#         "satellite_id": "101f",
#         "shadow_percent": 2,
#         "snow_ice_percent": 0,
#         "strip_id": "2614981",
#         "sun_azimuth": 132.2,
#         "sun_elevation": 56.4,
#         "updated": "2019-08-21T04:23:46Z",
#         "view_angle": 3,
#         "visible_confidence_percent": 49,
#         "visible_percent": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183414_101f",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183414_101f/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183414_101f/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.udm2:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_udm2:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -122.08366955656777,
#               37.640603970934706
#             ],
#             [
#               -122.36859122323871,
#               37.69030701410244
#             ],
#             [
#               -122.35113789503121,
#               37.75271171486281
#             ],
#             [
#               -122.3508645431144,
#               37.75266415592813
#             ],
#             [
#               -122.34794881261776,
#               37.763397160251486
#             ],
#             [
#               -122.06285838206739,
#               37.71390362501293
#             ],
#             [
#               -122.06747602925194,
#               37.69705018212484
#             ],
#             [
#               -122.06777286050684,
#               37.697102191246834
#             ],
#             [
#               -122.08366955656777,
#               37.640603970934706
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20190820_183414_101f",
#       "properties": {
#         "acquired": "2019-08-20T18:34:14.676928Z",
#         "anomalous_pixels": 0.46,
#         "clear_confidence_percent": 37,
#         "clear_percent": 1,
#         "cloud_cover": 0.95,
#         "cloud_percent": 97,
#         "columns": 8978,
#         "epsg_code": 32610,
#         "ground_control": false,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "light_haze_percent": 0,
#         "origin_x": 555666,
#         "origin_y": 4179765,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2019-08-21T00:10:06Z",
#         "quality_category": "test",
#         "rows": 4477,
#         "satellite_id": "101f",
#         "shadow_percent": 2,
#         "snow_ice_percent": 0,
#         "strip_id": "2614981",
#         "sun_azimuth": 132.3,
#         "sun_elevation": 56.4,
#         "updated": "2019-08-21T04:23:30Z",
#         "view_angle": 3,
#         "visible_confidence_percent": 50,
#         "visible_percent": 3
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183413_101f",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183413_101f/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183413_101f/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.udm2:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_udm2:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -122.32950068673092,
#               37.82992528828694
#             ],
#             [
#               -122.04489785876024,
#               37.780560198250654
#             ],
#             [
#               -122.06495104831698,
#               37.707229147707366
#             ],
#             [
#               -122.34974729055314,
#               37.75677683938229
#             ],
#             [
#               -122.33269243152594,
#               37.819556947449264
#             ],
#             [
#               -122.33233372693446,
#               37.819494367060244
#             ],
#             [
#               -122.32950068673092,
#               37.82992528828694
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20190820_183413_101f",
#       "properties": {
#         "acquired": "2019-08-20T18:34:13.616294Z",
#         "anomalous_pixels": 0.74,
#         "clear_confidence_percent": 33,
#         "clear_percent": 0,
#         "cloud_cover": 0.98,
#         "cloud_percent": 100,
#         "columns": 8943,
#         "epsg_code": 32610,
#         "ground_control": false,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "light_haze_percent": 0,
#         "origin_x": 557277,
#         "origin_y": 4187157,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2019-08-21T00:10:06Z",
#         "quality_category": "test",
#         "rows": 4472,
#         "satellite_id": "101f",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "2614981",
#         "sun_azimuth": 132.4,
#         "sun_elevation": 56.3,
#         "updated": "2019-08-21T04:23:39Z",
#         "view_angle": 3,
#         "visible_confidence_percent": 54,
#         "visible_percent": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183412_101f",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183412_101f/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183412_101f/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.udm2:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_udm2:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -122.31946745072217,
#               37.86686648464734
#             ],
#             [
#               -122.31392803076193,
#               37.886656971539125
#             ],
#             [
#               -122.31374670790638,
#               37.88662531852699
#             ],
#             [
#               -122.31090129532163,
#               37.89711467687583
#             ],
#             [
#               -122.02483821702718,
#               37.847429924828816
#             ],
#             [
#               -122.03983694209401,
#               37.793469333171124
#             ],
#             [
#               -122.04546568816383,
#               37.7737858488334
#             ],
#             [
#               -122.33121150935911,
#               37.82362624034365
#             ],
#             [
#               -122.31946745072217,
#               37.86686648464734
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20190820_183412_101f",
#       "properties": {
#         "acquired": "2019-08-20T18:34:12.555659Z",
#         "anomalous_pixels": 0.41,
#         "clear_confidence_percent": 75,
#         "clear_percent": 20,
#         "cloud_cover": 0.81,
#         "cloud_percent": 79,
#         "columns": 8979,
#         "epsg_code": 32610,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "light_haze_percent": 0,
#         "origin_x": 558858,
#         "origin_y": 4194624,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2019-08-21T00:10:06Z",
#         "quality_category": "test",
#         "rows": 4493,
#         "satellite_id": "101f",
#         "shadow_percent": 1,
#         "snow_ice_percent": 0,
#         "strip_id": "2614981",
#         "sun_azimuth": 132.5,
#         "sun_elevation": 56.3,
#         "updated": "2019-08-21T04:23:41Z",
#         "view_angle": 3,
#         "visible_confidence_percent": 62,
#         "visible_percent": 21
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_172432_104b",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_172432_104b/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20190820_172432_104b/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.udm2:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_udm2:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -122.9436890389349,
#               38.2611759479141
#             ],
#             [
#               -122.94975023847734,
#               38.28460860688583
#             ],
#             [
#               -122.94960668166073,
#               38.28463188715023
#             ],
#             [
#               -122.95233144741671,
#               38.294865444789096
#             ],
#             [
#               -122.68869411784465,
#               38.338017000614286
#             ],
#             [
#               -122.67836208460557,
#               38.29875688399507
#             ],
#             [
#               -122.6714115910449,
#               38.271415508050936
#             ],
#             [
#               -122.93502216331314,
#               38.22847453319284
#             ],
#             [
#               -122.9436890389349,
#               38.2611759479141
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20190820_172432_104b",
#       "properties": {
#         "acquired": "2019-08-20T17:24:32.612597Z",
#         "anomalous_pixels": 0.01,
#         "clear_confidence_percent": 35,
#         "clear_percent": 30,
#         "cloud_cover": 0.84,
#         "cloud_percent": 66,
#         "columns": 8192,
#         "epsg_code": 32610,
#         "ground_control": false,
#         "gsd": 3.6,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "light_haze_percent": 3,
#         "origin_x": 504168,
#         "origin_y": 4243368,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2019-08-21T00:04:00Z",
#         "quality_category": "test",
#         "rows": 4067,
#         "satellite_id": "104b",
#         "shadow_percent": 1,
#         "snow_ice_percent": 0,
#         "strip_id": "2614876",
#         "sun_azimuth": 112.3,
#         "sun_elevation": 44,
#         "updated": "2019-08-21T04:49:21Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 43,
#         "visible_percent": 34
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_172431_104b",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_172431_104b/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20190820_172431_104b/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.udm2:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_udm2:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -122.92047821255015,
#               38.172969255320524
#             ],
#             [
#               -122.93637107417659,
#               38.23428434328081
#             ],
#             [
#               -122.67297752917186,
#               38.27757548829706
#             ],
#             [
#               -122.67032845715272,
#               38.267154750065146
#             ],
#             [
#               -122.67022015231137,
#               38.267172383776604
#             ],
#             [
#               -122.66415607394778,
#               38.243809777563996
#             ],
#             [
#               -122.65585515093817,
#               38.21099193500194
#             ],
#             [
#               -122.91911967825024,
#               38.16786968289396
#             ],
#             [
#               -122.92047821255015,
#               38.172969255320524
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20190820_172431_104b",
#       "properties": {
#         "acquired": "2019-08-20T17:24:31.663111Z",
#         "anomalous_pixels": 0.01,
#         "clear_confidence_percent": 30,
#         "clear_percent": 8,
#         "cloud_cover": 0.97,
#         "cloud_percent": 90,
#         "columns": 8188,
#         "epsg_code": 32610,
#         "ground_control": false,
#         "gsd": 3.6,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "light_haze_percent": 3,
#         "origin_x": 505566,
#         "origin_y": 4236666,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2019-08-21T00:04:00Z",
#         "quality_category": "test",
#         "rows": 4075,
#         "satellite_id": "104b",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "2614876",
#         "sun_azimuth": 112.3,
#         "sun_elevation": 44,
#         "updated": "2019-08-21T04:49:03Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 38,
#         "visible_percent": 10
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_172430_104b",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_172430_104b/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20190820_172430_104b/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.udm2:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_udm2:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -122.64267026942917,
#               38.159596385689674
#             ],
#             [
#               -122.89448814634949,
#               38.1260963820659
#             ],
#             [
#               -122.90966757663027,
#               38.19630636458636
#             ],
#             [
#               -122.66056943076289,
#               38.229629921753805
#             ],
#             [
#               -122.65477548276866,
#               38.206723448236666
#             ],
#             [
#               -122.6545205253718,
#               38.20676517765225
#             ],
#             [
#               -122.64267026942917,
#               38.159596385689674
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20190820_172430_104b",
#       "properties": {
#         "acquired": "2019-08-20T17:24:30.713625Z",
#         "anomalous_pixels": 0.12,
#         "clear_confidence_percent": 34,
#         "clear_percent": 0,
#         "cloud_cover": 0.99,
#         "cloud_percent": 100,
#         "columns": 7799,
#         "epsg_code": 32610,
#         "ground_control": false,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "light_haze_percent": 0,
#         "origin_x": 507909,
#         "origin_y": 4231350,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2019-08-21T00:04:00Z",
#         "quality_category": "test",
#         "rows": 3847,
#         "satellite_id": "104b",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "2614876",
#         "sun_azimuth": 112.3,
#         "sun_elevation": 44.1,
#         "updated": "2019-08-21T04:48:32Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 42,
#         "visible_percent": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183802_1001",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183802_1001/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20190820_183802_1001/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.udm2:download",
# ...
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20190729_172630_0f3c/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.udm2:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_udm2:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -122.64114584650797,
#               37.607248455998544
#             ],
#             [
#               -122.3857607736463,
#               37.648540664075924
#             ],
#             [
#               -122.38157485858876,
#               37.63224850967617
#             ],
#             [
#               -122.38158949260539,
#               37.63224615978684
#             ],
#             [
#               -122.36981103710579,
#               37.584414373668395
#             ],
#             [
#               -122.61485446516043,
#               37.54836823070103
#             ],
#             [
#               -122.62786232878999,
#               37.592700358690124
#             ],
#             [
#               -122.63692334554247,
#               37.591245366041406
#             ],
#             [
#               -122.64114584650797,
#               37.607248455998544
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20190729_172630_0f3c",
#       "properties": {
#         "acquired": "2019-07-29T17:26:30.677293Z",
#         "anomalous_pixels": 0.62,
#         "clear_confidence_percent": 77,
#         "clear_percent": 14,
#         "cloud_cover": 0.75,
#         "cloud_percent": 83,
#         "columns": 7990,
#         "epsg_code": 32610,
#         "ground_control": false,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "light_haze_percent": 3,
#         "origin_x": 531672,
#         "origin_y": 4167000,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2019-07-30T01:59:08Z",
#         "quality_category": "test",
#         "rows": 3741,
#         "satellite_id": "0f3c",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "2559529",
#         "sun_azimuth": 104.9,
#         "sun_elevation": 48.5,
#         "updated": "2019-07-30T04:31:04Z",
#         "view_angle": 1,
#         "visible_confidence_percent": 59,
#         "visible_percent": 17
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190729_183457_103b",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190729_183457_103b/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20190729_183457_103b/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.udm2:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_udm2:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -122.27159503654262,
#               37.64848479682632
#             ],
#             [
#               -122.55856545624368,
#               37.69876794460664
#             ],
#             [
#               -122.53786582644607,
#               37.77245296454867
#             ],
#             [
#               -122.25153207247429,
#               37.72263138374475
#             ],
#             [
#               -122.2556084999987,
#               37.70829636517543
#             ],
#             [
#               -122.25459695135002,
#               37.70811972480998
#             ],
#             [
#               -122.27159503654262,
#               37.64848479682632
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20190729_183457_103b",
#       "properties": {
#         "acquired": "2019-07-29T18:34:57.970027Z",
#         "anomalous_pixels": 0.52,
#         "clear_confidence_percent": 58,
#         "clear_percent": 17,
#         "cloud_cover": 0.73,
#         "cloud_percent": 80,
#         "columns": 9016,
#         "epsg_code": 32610,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "light_haze_percent": 1,
#         "origin_x": 538914,
#         "origin_y": 4180671,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2019-07-30T00:30:50Z",
#         "quality_category": "test",
#         "rows": 4536,
#         "satellite_id": "103b",
#         "shadow_percent": 2,
#         "snow_ice_percent": 0,
#         "strip_id": "2559087",
#         "sun_azimuth": 123.3,
#         "sun_elevation": 60.7,
#         "updated": "2019-07-30T04:33:34Z",
#         "view_angle": 3,
#         "visible_confidence_percent": 47,
#         "visible_percent": 20
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190729_183456_103b",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190729_183456_103b/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20190729_183456_103b/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.udm2:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_udm2:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -122.25442982004368,
#               37.71244126875616
#             ],
#             [
#               -122.54158181548158,
#               37.76257493619333
#             ],
#             [
#               -122.52094368239885,
#               37.8362734925252
#             ],
#             [
#               -122.23456453382038,
#               37.786451447298525
#             ],
#             [
#               -122.23840842757811,
#               37.77284004562531
#             ],
#             [
#               -122.23730918671166,
#               37.772647072799806
#             ],
#             [
#               -122.25442982004368,
#               37.71244126875616
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20190729_183456_103b",
#       "properties": {
#         "acquired": "2019-07-29T18:34:56.925121Z",
#         "anomalous_pixels": 0.64,
#         "clear_confidence_percent": 63,
#         "clear_percent": 7,
#         "cloud_cover": 0.89,
#         "cloud_percent": 92,
#         "columns": 9008,
#         "epsg_code": 32610,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "light_haze_percent": 0,
#         "origin_x": 540375,
#         "origin_y": 4187760,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2019-07-30T00:30:50Z",
#         "quality_category": "test",
#         "rows": 4530,
#         "satellite_id": "103b",
#         "shadow_percent": 1,
#         "snow_ice_percent": 0,
#         "strip_id": "2559087",
#         "sun_azimuth": 123.4,
#         "sun_elevation": 60.7,
#         "updated": "2019-07-30T04:32:39Z",
#         "view_angle": 3,
#         "visible_confidence_percent": 61,
#         "visible_percent": 8
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190729_183455_103b",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190729_183455_103b/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20190729_183455_103b/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.udm2:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_udm2:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -122.23723386478784,
#               37.776999225596526
#             ],
#             [
#               -122.5244673029634,
#               37.827404339800495
#             ],
#             [
#               -122.50360791533835,
#               37.90120165768198
#             ],
#             [
#               -122.21583331423199,
#               37.8508848475506
#             ],
#             [
#               -122.22121781693546,
#               37.83195993085443
#             ],
#             [
#               -122.2216894164428,
#               37.83204282033353
#             ],
#             [
#               -122.23723386478784,
#               37.776999225596526
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20190729_183455_103b",
#       "properties": {
#         "acquired": "2019-07-29T18:34:55.879691Z",
#         "anomalous_pixels": 0.39,
#         "clear_confidence_percent": 71,
#         "clear_percent": 29,
#         "cloud_cover": 0.68,
#         "cloud_percent": 68,
#         "columns": 9047,
#         "epsg_code": 32610,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "light_haze_percent": 1,
#         "origin_x": 541848,
#         "origin_y": 4194972,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2019-07-30T00:30:50Z",
#         "quality_category": "test",
#         "rows": 4542,
#         "satellite_id": "103b",
#         "shadow_percent": 2,
#         "snow_ice_percent": 0,
#         "strip_id": "2559087",
#         "sun_azimuth": 123.6,
#         "sun_elevation": 60.6,
#         "updated": "2019-07-30T04:33:14Z",
#         "view_angle": 2.9,
#         "visible_confidence_percent": 53,
#         "visible_percent": 32
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190729_172634_0f3c",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190729_172634_0f3c/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20190729_172634_0f3c/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.udm2:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_udm2:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -122.43076014045998,
#               37.82002800767333
#             ],
#             [
#               -122.68397621142151,
#               37.779852680233084
#             ],
#             [
#               -122.7026136395195,
#               37.844402992911974
#             ],
#             [
#               -122.44740368717396,
#               37.88578397212656
#             ],
#             [
#               -122.44469369234073,
#               37.874995239883006
#             ],
#             [
#               -122.4442440974663,
#               37.875067711837886
#             ],
#             [
#               -122.43076014045998,
#               37.82002800767333
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20190729_172634_0f3c",
#       "properties": {
#         "acquired": "2019-07-29T17:26:34.41966Z",
#         "anomalous_pixels": 0.13,
#         "clear_confidence_percent": 54,
#         "clear_percent": 16,
#         "cloud_cover": 0.74,
#         "cloud_percent": 79,
#         "columns": 7979,
#         "epsg_code": 32610,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "light_haze_percent": 0,
#         "origin_x": 526164,
#         "origin_y": 4193289,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2019-07-30T00:21:32Z",
#         "quality_category": "standard",
#         "rows": 3951,
#         "satellite_id": "0f3c",
#         "shadow_percent": 3,
#         "snow_ice_percent": 1,
#         "strip_id": "2559529",
#         "sun_azimuth": 105.1,
#         "sun_elevation": 48.4,
#         "updated": "2019-07-30T04:32:14Z",
#         "view_angle": 1,
#         "visible_confidence_percent": 49,
#         "visible_percent": 21
#       },
#       "type": "Feature"
#     }
#   ],
#   "type": "FeatureCollection"
# }

# %%
# gets samples of all item types
item_types = [['PSScene4Band'],['PSScene3Band'],['PSOrthoTile'],
              ['REOrthoTile'],['REScene'],['SkySatScene'],
              ['SkySatCollect'],['Landsat8L1G'],['Sentinel2L1C']]

for entry in item_types:
    request = api.filters.build_search_request(query, entry)
    results = client.quick_search(request)

    for item in results.items_iter(1):
        print(json.dumps(item, indent=2))

# %%
mosaics = client.get_mosaics()

# %%
for item in mosaics.items_iter(100):
    print(json.dumps(item, indent=2))
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/49329058-74fa-43d9-aa1b-d6c8d8cdc9b8?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/49329058-74fa-43d9-aa1b-d6c8d8cdc9b8/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/EEA39_demo_narrow_toi_coverage_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -10.722656,
#     47.279229,
#     23.378906,
#     62.186014
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-06-15T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "49329058-74fa-43d9-aa1b-d6c8d8cdc9b8",
#   "item_types": [
#     "PSScene3Band"
#   ],
#   "last_acquired": "2018-08-22T00:00:00.000Z",
#   "level": 15,
#   "name": "EEA39_demo_narrow_toi_coverage_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/eb4e0de7-08ce-41cb-89d4-1fd96981f3c0?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/eb4e0de7-08ce-41cb-89d4-1fd96981f3c0/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/ak_humboldt_co_skysat_v3_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -124.453124982659,
#     39.960280349691,
#     -123.376464826558,
#     41.426253190367
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2019-03-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 0.5971642834779395
#   },
#   "id": "eb4e0de7-08ce-41cb-89d4-1fd96981f3c0",
#   "item_types": [
#     "unknown"
#   ],
#   "last_acquired": "2019-04-15T00:00:00.000Z",
#   "level": 18,
#   "name": "ak_humboldt_co_skysat_v3_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/f4c71021-2a76-4815-a9f5-1b5ea24c7dca?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/f4c71021-2a76-4815-a9f5-1b5ea24c7dca/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/ak_miro_skysat_v2_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -1.40625,
#     6.751896,
#     -0.769043,
#     7.384258
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2019-01-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 0.5971642834779395
#   },
#   "id": "f4c71021-2a76-4815-a9f5-1b5ea24c7dca",
#   "item_types": [
#     "SkySatScene"
#   ],
#   "last_acquired": "2019-02-28T00:33:39.000Z",
#   "level": 18,
#   "name": "ak_miro_skysat_v2_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/c74271d0-8673-4d8c-be63-b95747b7fe60?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/c74271d0-8673-4d8c-be63-b95747b7fe60/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/ak_skysat_aguarague_v2_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -63.544922,
#     -20.96144,
#     -63.193359,
#     -20.344627
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-07-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 0.5971642834779395
#   },
#   "id": "c74271d0-8673-4d8c-be63-b95747b7fe60",
#   "item_types": [
#     "SkySatScene"
#   ],
#   "last_acquired": "2018-09-01T00:33:39.000Z",
#   "level": 18,
#   "name": "ak_skysat_aguarague_v2_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/e212e3e7-1957-48f2-847c-60d8bde6b5bb?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/e212e3e7-1957-48f2-847c-60d8bde6b5bb/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/ak_skysat_aguarague_v4_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -63.544922,
#     -20.96144,
#     -63.193359,
#     -20.344627
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-07-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 0.5971642834779395
#   },
#   "id": "e212e3e7-1957-48f2-847c-60d8bde6b5bb",
#   "item_types": [
#     "SkySatScene"
#   ],
#   "last_acquired": "2018-09-01T00:33:39.000Z",
#   "level": 18,
#   "name": "ak_skysat_aguarague_v4_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/7275452f-597c-4df7-a708-2ff8e2e06be2?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/7275452f-597c-4df7-a708-2ff8e2e06be2/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/ak_skysat_aguarague_v5_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -63.544922,
#     -20.96144,
#     -63.193359,
#     -20.344627
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-07-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 0.5971642834779395
#   },
#   "id": "7275452f-597c-4df7-a708-2ff8e2e06be2",
#   "item_types": [
#     "SkySatScene"
#   ],
#   "last_acquired": "2018-09-01T00:33:39.000Z",
#   "level": 18,
#   "name": "ak_skysat_aguarague_v5_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/448f4ac3-f017-477a-aa7f-1f792fb3b7c4?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/448f4ac3-f017-477a-aa7f-1f792fb3b7c4/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/ak_skysat_la_v6_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -119,
#     34,
#     -118,
#     35
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2017-08-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 0.5971642834779395
#   },
#   "id": "448f4ac3-f017-477a-aa7f-1f792fb3b7c4",
#   "interval": "1 year",
#   "item_types": [
#     "SkySatScene"
#   ],
#   "last_acquired": "2017-12-01T00:33:39.000Z",
#   "level": 18,
#   "name": "ak_skysat_la_v6_mosaic",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/80dfe37c-8249-4d93-a599-306d9380ef40?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/80dfe37c-8249-4d93-a599-306d9380ef40/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/ak_skysat_permian_basin_v3_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -104,
#     31,
#     -103,
#     32
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2017-11-19T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 0.5971642834779395
#   },
#   "id": "80dfe37c-8249-4d93-a599-306d9380ef40",
#   "item_types": [
#     "SkySatScene"
#   ],
#   "last_acquired": "2018-01-31T00:33:39.000Z",
#   "level": 18,
#   "name": "ak_skysat_permian_basin_v3_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/eb0508b7-f798-4d25-9f42-a0d4e626b497?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/eb0508b7-f798-4d25-9f42-a0d4e626b497/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/ak_skysat_perth_v1_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     115,
#     -33,
#     116,
#     -31
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-06-09T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 0.5971642834779395
#   },
#   "id": "eb0508b7-f798-4d25-9f42-a0d4e626b497",
#   "item_types": [
#     "SkySatScene"
#   ],
#   "last_acquired": "2018-06-17T00:33:39.000Z",
#   "level": 18,
#   "name": "ak_skysat_perth_v1_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/a5b65fef-87fd-4f52-bc3a-3a2944499943?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/a5b65fef-87fd-4f52-bc3a-3a2944499943/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/ak_yuba_co_skysat_v1_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -121.68457,
#     38.873929,
#     -120.959473,
#     39.67337
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-10-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 0.5971642834779395
#   },
#   "id": "a5b65fef-87fd-4f52-bc3a-3a2944499943",
#   "item_types": [
#     "SkySatScene"
#   ],
#   "last_acquired": "2018-11-01T00:00:00.000Z",
#   "level": 18,
#   "name": "ak_yuba_co_skysat_v1_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/b2d47378-94a4-4419-aca9-a92a2ed1098b?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/b2d47378-94a4-4419-aca9-a92a2ed1098b/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/alabama_2019_tornado_after_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -85.78125,
#     32.249974,
#     -84.199219,
#     32.990236
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2019-03-04T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "b2d47378-94a4-4419-aca9-a92a2ed1098b",
#   "item_types": [
#     "PSScene3Band",
#     "REOrthoTile"
#   ],
#   "last_acquired": "2019-03-07T00:00:00.000Z",
#   "level": 15,
#   "name": "alabama_2019_tornado_after_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/9d4c05ce-5f43-4dae-a1b6-76a7cc5a81a0?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/9d4c05ce-5f43-4dae-a1b6-76a7cc5a81a0/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/an137_sf_south_bay_201803_analytic_sr_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -123,
#     37,
#     -122,
#     38
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "uint16",
#   "first_acquired": "2018-03-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "9d4c05ce-5f43-4dae-a1b6-76a7cc5a81a0",
#   "item_types": [
#     "PSScene4Band"
#   ],
#   "last_acquired": "2018-04-01T00:00:00.000Z",
#   "level": 15,
#   "name": "an137_sf_south_bay_201803_analytic_sr_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/3d8a55e8-0988-4db4-b049-48ecdcb8895d?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/3d8a55e8-0988-4db4-b049-48ecdcb8895d/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/an137_syria_201803_analytic_sr_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     36,
#     32,
#     43,
#     37
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "uint16",
#   "first_acquired": "2018-03-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "3d8a55e8-0988-4db4-b049-48ecdcb8895d",
#   "item_types": [
#     "PSScene4Band"
#   ],
#   "last_acquired": "2018-04-01T00:00:00.000Z",
#   "level": 15,
#   "name": "an137_syria_201803_analytic_sr_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/91a35ed4-21c0-4c47-8a4a-4f8627fc21fa?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/91a35ed4-21c0-4c47-8a4a-4f8627fc21fa/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/ank_brazil_forest_2017_11_05_2017_11_11_analytic_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -65,
#     -32,
#     -36,
#     -1
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "uint16",
#   "first_acquired": "2017-11-05T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "91a35ed4-21c0-4c47-8a4a-4f8627fc21fa",
#   "item_types": [
#     "PSScene4Band"
#   ],
#   "last_acquired": "2017-11-12T00:00:00.000Z",
#   "level": 15,
#   "name": "ank_brazil_forest_2017_11_05_2017_11_11_analytic_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/d7ebb1b3-9538-4386-956c-f096a971347f?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/d7ebb1b3-9538-4386-956c-f096a971347f/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/ank_brazil_forest_2017_11_12_2017_11_18_analytic_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -65,
#     -32,
#     -36,
#     -1
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "uint16",
#   "first_acquired": "2017-11-12T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "d7ebb1b3-9538-4386-956c-f096a971347f",
#   "item_types": [
#     "PSScene4Band"
#   ],
#   "last_acquired": "2017-11-19T00:00:00.000Z",
#   "level": 15,
#   "name": "ank_brazil_forest_2017_11_12_2017_11_18_analytic_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/334b8868-9dd5-4839-90ba-39edc1f30694?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/334b8868-9dd5-4839-90ba-39edc1f30694/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/ank_brazil_forest_2017_11_19_2017_11_25_analytic_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -65,
#     -32,
#     -36,
#     -1
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "uint16",
#   "first_acquired": "2017-11-19T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "334b8868-9dd5-4839-90ba-39edc1f30694",
#   "item_types": [
#     "PSScene4Band"
#   ],
#   "last_acquired": "2017-11-26T00:00:00.000Z",
#   "level": 15,
#   "name": "ank_brazil_forest_2017_11_19_2017_11_25_analytic_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/8f25c131-3230-482a-bfc4-72d93facea50?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/8f25c131-3230-482a-bfc4-72d93facea50/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/ank_brazil_forest_2017_11_26_2017_12_02_analytic_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -65,
#     -32,
#     -36,
#     -1
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "uint16",
#   "first_acquired": "2017-11-26T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "8f25c131-3230-482a-bfc4-72d93facea50",
#   "item_types": [
#     "PSScene4Band"
#   ],
#   "last_acquired": "2017-12-03T00:00:00.000Z",
#   "level": 15,
#   "name": "ank_brazil_forest_2017_11_26_2017_12_02_analytic_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/09f75a17-1e5b-4e8b-b689-75baad794090?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/09f75a17-1e5b-4e8b-b689-75baad794090/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/ank_palawan_central_20170801_20171101_analytic_for_rgb_web_tiles_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     118,
#     9,
#     119,
#     10
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "uint16",
#   "first_acquired": "2017-08-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 2048,
#     "resolution": 2.388657133911758
#   },
#   "id": "09f75a17-1e5b-4e8b-b689-75baad794090",
#   "item_types": [
#     "PSScene4Band"
#   ],
#   "last_acquired": "2017-11-02T00:00:00.000Z",
#   "level": 16,
#   "name": "ank_palawan_central_20170801_20171101_analytic_for_rgb_web_tiles_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/c4ab8ec9-8a27-47b1-908d-adaea79ce6ec?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/c4ab8ec9-8a27-47b1-908d-adaea79ce6ec/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/ank_palawan_central_20170801_20171101_analytic_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     118,
#     9,
#     119,
#     10
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "uint16",
#   "first_acquired": "2017-08-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 2048,
#     "resolution": 2.388657133911758
#   },
#   "id": "c4ab8ec9-8a27-47b1-908d-adaea79ce6ec",
#   "item_types": [
#     "PSScene4Band"
#   ],
#   "last_acquired": "2017-11-02T00:00:00.000Z",
#   "level": 16,
#   "name": "ank_palawan_central_20170801_20171101_analytic_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/e95d95f3-087f-4860-a6c1-67b231f2777e?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/e95d95f3-087f-4860-a6c1-67b231f2777e/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/atlas_ai_demo_analytic_sr_2018_10_14_2018_10_28_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     34.628906,
#     0.527336,
#     34.804687,
#     0.703107
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "uint16",
#   "first_acquired": "2018-10-14T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 2.388657133911758
#   },
#   "id": "e95d95f3-087f-4860-a6c1-67b231f2777e",
#   "interval": "14 days",
#   "item_types": [
#     "PSScene4Band"
#   ],
#   "last_acquired": "2018-10-28T00:00:00.000Z",
#   "level": 16,
#   "name": "atlas_ai_demo_analytic_sr_2018_10_14_2018_10_28_mosaic",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/e71690d3-bef0-43a9-ace4-35dc64d56349?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/e71690d3-bef0-43a9-ace4-35dc64d56349/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/atlas_ai_demo_analytic_sr_2018_10_28_2018_11_11_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     34.628906,
#     0.527336,
#     34.804687,
#     0.703107
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "uint16",
#   "first_acquired": "2018-10-28T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 2.388657133911758
#   },
#   "id": "e71690d3-bef0-43a9-ace4-35dc64d56349",
#   "interval": "14 days",
#   "item_types": [
#     "PSScene4Band"
#   ],
#   "last_acquired": "2018-11-11T00:00:00.000Z",
#   "level": 16,
#   "name": "atlas_ai_demo_analytic_sr_2018_10_28_2018_11_11_mosaic",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/4634a999-db52-446c-b334-2210755b5aaf?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/4634a999-db52-446c-b334-2210755b5aaf/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/atlas_ai_demo_analytic_sr_2018_11_11_2018_11_25_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     34.628906,
#     0.527336,
#     34.804687,
#     0.703107
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "uint16",
#   "first_acquired": "2018-11-11T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 2.388657133911758
#   },
#   "id": "4634a999-db52-446c-b334-2210755b5aaf",
#   "interval": "14 days",
#   "item_types": [
#     "PSScene4Band"
#   ],
#   "last_acquired": "2018-11-25T00:00:00.000Z",
#   "level": 16,
#   "name": "atlas_ai_demo_analytic_sr_2018_11_11_2018_11_25_mosaic",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/598426f9-34c8-4362-8668-f52d6dc6ce37?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/598426f9-34c8-4362-8668-f52d6dc6ce37/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/atlas_ai_demo_analytic_sr_2018_11_25_2018_12_09_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     34.628906,
#     0.527336,
#     34.804687,
#     0.703107
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "uint16",
#   "first_acquired": "2018-11-25T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 2.388657133911758
#   },
#   "id": "598426f9-34c8-4362-8668-f52d6dc6ce37",
#   "interval": "14 days",
#   "item_types": [
#     "PSScene4Band"
#   ],
#   "last_acquired": "2018-12-09T00:00:00.000Z",
#   "level": 16,
#   "name": "atlas_ai_demo_analytic_sr_2018_11_25_2018_12_09_mosaic",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/9b8c29cb-82a7-4222-ae76-bdee25871e17?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/9b8c29cb-82a7-4222-ae76-bdee25871e17/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/atlas_ai_demo_normalized_sr_2018_10_14_2018_10_28_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     34.628906,
#     0.527336,
#     34.804687,
#     0.703107
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "uint16",
#   "first_acquired": "2018-10-14T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 2.388657133911758
#   },
#   "id": "9b8c29cb-82a7-4222-ae76-bdee25871e17",
#   "interval": "14 days",
#   "item_types": [
#     "PSScene4Band"
#   ],
#   "last_acquired": "2018-10-28T00:00:00.000Z",
#   "level": 16,
#   "name": "atlas_ai_demo_normalized_sr_2018_10_14_2018_10_28_mosaic",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/01c69c30-a597-442f-a5cf-b72a7df5c61c?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/01c69c30-a597-442f-a5cf-b72a7df5c61c/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/atlas_ai_demo_normalized_sr_2018_10_28_2018_11_11_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     34.628906,
#     0.527336,
#     34.804687,
#     0.703107
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "uint16",
#   "first_acquired": "2018-10-28T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 2.388657133911758
#   },
#   "id": "01c69c30-a597-442f-a5cf-b72a7df5c61c",
#   "interval": "14 days",
#   "item_types": [
#     "PSScene4Band"
#   ],
#   "last_acquired": "2018-11-11T00:00:00.000Z",
#   "level": 16,
#   "name": "atlas_ai_demo_normalized_sr_2018_10_28_2018_11_11_mosaic",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/0b1bc8bc-17b6-4c8f-9163-a7145ec6bfbe?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/0b1bc8bc-17b6-4c8f-9163-a7145ec6bfbe/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/atlas_ai_demo_normalized_sr_2018_11_11_2018_11_25_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     34.628906,
#     0.527336,
#     34.804687,
#     0.703107
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "uint16",
#   "first_acquired": "2018-11-11T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 2.388657133911758
#   },
#   "id": "0b1bc8bc-17b6-4c8f-9163-a7145ec6bfbe",
#   "interval": "14 days",
#   "item_types": [
#     "PSScene4Band"
#   ],
#   "last_acquired": "2018-11-25T00:00:00.000Z",
#   "level": 16,
#   "name": "atlas_ai_demo_normalized_sr_2018_11_11_2018_11_25_mosaic",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/ccea0c4c-d065-4479-a90d-85149f56c6eb?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/ccea0c4c-d065-4479-a90d-85149f56c6eb/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/atlas_ai_demo_normalized_sr_2018_11_25_2018_12_09_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     34.628906,
#     0.527336,
#     34.804687,
#     0.703107
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "uint16",
#   "first_acquired": "2018-11-25T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 2.388657133911758
#   },
#   "id": "ccea0c4c-d065-4479-a90d-85149f56c6eb",
#   "interval": "14 days",
#   "item_types": [
#     "PSScene4Band"
#   ],
#   "last_acquired": "2018-12-09T00:00:00.000Z",
#   "level": 16,
#   "name": "atlas_ai_demo_normalized_sr_2018_11_25_2018_12_09_mosaic",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/17ac620c-9aa1-4d7b-8096-52189fed130e?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/17ac620c-9aa1-4d7b-8096-52189fed130e/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/aus_nz_normalized_sr_2018_12_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     112.851562484382,
#     -47.398349195248,
#     178.769531225227,
#     -9.102096737417
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "uint16",
#   "first_acquired": "2018-12-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "17ac620c-9aa1-4d7b-8096-52189fed130e",
#   "item_types": [
#     "PSScene4Band"
#   ],
#   "last_acquired": "2019-01-01T00:00:00.000Z",
#   "level": 15,
#   "name": "aus_nz_normalized_sr_2018_12_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/9d54d511-b6fe-4542-930c-9bb8c9591f84?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/9d54d511-b6fe-4542-930c-9bb8c9591f84/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/bae_rubicon_omaha_flood_2019_analytic_sr_after_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -96.50390623654,
#     40.979898064944,
#     -95.449218736687,
#     41.640078379959
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "uint16",
#   "first_acquired": "2019-03-10T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "9d54d511-b6fe-4542-930c-9bb8c9591f84",
#   "item_types": [
#     "PSScene4Band"
#   ],
#   "last_acquired": "2019-03-21T00:00:00.000Z",
#   "level": 15,
#   "name": "bae_rubicon_omaha_flood_2019_analytic_sr_after_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/51348772-0bb5-48f3-8006-6dee594acaed?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/51348772-0bb5-48f3-8006-6dee594acaed/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/bae_rubicon_omaha_flood_2019_analytic_sr_before_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -96.50390623654,
#     40.979898064944,
#     -95.449218736687,
#     41.640078379959
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "uint16",
#   "first_acquired": "2019-01-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "51348772-0bb5-48f3-8006-6dee594acaed",
#   "item_types": [
#     "PSScene4Band"
#   ],
#   "last_acquired": "2019-03-01T00:00:00.000Z",
#   "level": 15,
#   "name": "bae_rubicon_omaha_flood_2019_analytic_sr_before_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/9b576ea0-2080-4930-bbd2-63de30a9e97a?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/9b576ea0-2080-4930-bbd2-63de30a9e97a/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/bae_rubicon_omaha_flood_2019_normalized_sr_after_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -96.50390623654,
#     40.979898064944,
#     -95.449218736687,
#     41.640078379959
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "uint16",
#   "first_acquired": "2019-03-10T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "9b576ea0-2080-4930-bbd2-63de30a9e97a",
#   "item_types": [
#     "PSScene4Band"
#   ],
#   "last_acquired": "2019-03-21T00:00:00.000Z",
#   "level": 15,
#   "name": "bae_rubicon_omaha_flood_2019_normalized_sr_after_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/880c8c84-213d-4d7d-840b-cbfd3c52bd3f?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/880c8c84-213d-4d7d-840b-cbfd3c52bd3f/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/bae_rubicon_omaha_flood_2019_normalized_sr_before_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -96.50390623654,
#     40.979898064944,
#     -95.449218736687,
#     41.640078379959
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "uint16",
#   "first_acquired": "2019-01-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "880c8c84-213d-4d7d-840b-cbfd3c52bd3f",
#   "item_types": [
#     "PSScene4Band"
#   ],
#   "last_acquired": "2019-03-01T00:00:00.000Z",
#   "level": 15,
#   "name": "bae_rubicon_omaha_flood_2019_normalized_sr_before_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/cc277537-841d-4e0a-b0d6-14b31f43583f?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/cc277537-841d-4e0a-b0d6-14b31f43583f/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/bahrain_skysat_2018-07-01_to_2018-07-15_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     50.383301,
#     25.720735,
#     50.756836,
#     26.332807
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-07-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 0.5971642834779395
#   },
#   "id": "cc277537-841d-4e0a-b0d6-14b31f43583f",
#   "item_types": [
#     "SkySatScene"
#   ],
#   "last_acquired": "2018-07-15T00:33:39.000Z",
#   "level": 18,
#   "name": "bahrain_skysat_2018-07-01_to_2018-07-15_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/880fe44b-6517-4b13-93bb-57673735b903?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/880fe44b-6517-4b13-93bb-57673735b903/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/bahrain_skysat_2018-07-01_to_2018-08-01_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     50.339355,
#     25.76032,
#     50.756836,
#     26.352498
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-07-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 0.5971642834779395
#   },
#   "id": "880fe44b-6517-4b13-93bb-57673735b903",
#   "item_types": [
#     "SkySatScene"
#   ],
#   "last_acquired": "2018-08-01T00:33:39.000Z",
#   "level": 18,
#   "name": "bahrain_skysat_2018-07-01_to_2018-08-01_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/f1ec4620-b448-492d-913c-898e36cab377?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/f1ec4620-b448-492d-913c-898e36cab377/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/bahrain_skysat_2018-07-15_to_2018-08-01_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     50.339355,
#     25.720735,
#     50.756836,
#     26.411551
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-07-15T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 0.5971642834779395
#   },
#   "id": "f1ec4620-b448-492d-913c-898e36cab377",
#   "item_types": [
#     "SkySatScene"
#   ],
#   "last_acquired": "2018-08-01T00:33:39.000Z",
#   "level": 18,
#   "name": "bahrain_skysat_2018-07-15_to_2018-08-01_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/4df377bc-ef52-4918-be4a-6d8dbaa1c526?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/4df377bc-ef52-4918-be4a-6d8dbaa1c526/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/bahrain_skysat_2018-08-01_to_2018-08-15_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     50.383301,
#     25.562265,
#     50.844727,
#     26.372185
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-08-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 0.5971642834779395
#   },
#   "id": "4df377bc-ef52-4918-be4a-6d8dbaa1c526",
#   "item_types": [
#     "SkySatScene"
#   ],
#   "last_acquired": "2018-08-15T00:33:39.000Z",
#   "level": 18,
#   "name": "bahrain_skysat_2018-08-01_to_2018-08-15_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/d26e1eaf-bbf5-44e2-97bb-8f1683a28466?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/d26e1eaf-bbf5-44e2-97bb-8f1683a28466/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/bahrain_skysat_2018-08-01_to_2018-09-01_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     50.383301,
#     25.562265,
#     50.866699,
#     26.372185
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-08-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 0.5971642834779395
#   },
#   "id": "d26e1eaf-bbf5-44e2-97bb-8f1683a28466",
#   "item_types": [
#     "SkySatScene"
#   ],
#   "last_acquired": "2018-09-01T00:33:39.000Z",
#   "level": 18,
#   "name": "bahrain_skysat_2018-08-01_to_2018-09-01_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/4d37f72b-2223-4046-8c6e-d830dfa2d436?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/4d37f72b-2223-4046-8c6e-d830dfa2d436/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/bahrain_skysat_2018-08-15_to_2018-09-01_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     50.383301,
#     25.562265,
#     50.866699,
#     26.372185
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-08-15T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 0.5971642834779395
#   },
#   "id": "4d37f72b-2223-4046-8c6e-d830dfa2d436",
#   "item_types": [
#     "SkySatScene"
#   ],
#   "last_acquired": "2018-09-01T00:33:39.000Z",
#   "level": 18,
#   "name": "bahrain_skysat_2018-08-15_to_2018-09-01_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/134a4b08-5840-4285-892d-d7cde242aaa2?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/134a4b08-5840-4285-892d-d7cde242aaa2/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/bahrain_skysat_2018-09-01_to_2018-09-15_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     50.405273,
#     25.562265,
#     50.866699,
#     26.372185
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-09-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 0.5971642834779395
#   },
#   "id": "134a4b08-5840-4285-892d-d7cde242aaa2",
#   "item_types": [
#     "SkySatScene"
#   ],
#   "last_acquired": "2018-09-16T00:33:39.000Z",
#   "level": 18,
#   "name": "bahrain_skysat_2018-09-01_to_2018-09-15_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/0031e37d-7cf3-4df3-a374-af5a143885ae?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/0031e37d-7cf3-4df3-a374-af5a143885ae/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/bahrain_skysat_2018-09-01_to_2018-10-01_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     50.361328,
#     25.562265,
#     50.866699,
#     26.372185
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-09-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 0.5971642834779395
#   },
#   "id": "0031e37d-7cf3-4df3-a374-af5a143885ae",
#   "item_types": [
#     "SkySatScene"
#   ],
#   "last_acquired": "2018-10-01T00:33:39.000Z",
#   "level": 18,
#   "name": "bahrain_skysat_2018-09-01_to_2018-10-01_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/1500ed58-b413-4e59-b545-51f8ecd0a22c?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/1500ed58-b413-4e59-b545-51f8ecd0a22c/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/bahrain_skysat_2018-09-15_to_2018-10-01_mosaic/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     50.361328,
#     25.878994,
#     50.756836,
#     26.352498
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-09-16T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 0.5971642834779395
#   },
#   "id": "1500ed58-b413-4e59-b545-51f8ecd0a22c",
#   "item_types": [
#     "SkySatScene"
#   ],
#   "last_acquired": "2018-10-01T00:33:39.000Z",
#   "level": 18,
#   "name": "bahrain_skysat_2018-09-15_to_2018-10-01_mosaic",
#   "product_type": "basemap",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/b9f622eb-58db-4ebf-bbaa-c24caed03c2c?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/b9f622eb-58db-4ebf-bbaa-c24caed03c2c/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/basemap_medres_monthly_california_2018_01/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -124.628906,
#     32.249974,
#     -113.90625,
#     42.163403
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-01-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "b9f622eb-58db-4ebf-bbaa-c24caed03c2c",
#   "interval": "1 mon",
#   "item_types": [
#     "PSScene3Band",
#     "REOrthoTile"
#   ],
#   "last_acquired": "2018-02-01T00:00:00.000Z",
#   "level": 15,
#   "name": "basemap_medres_monthly_california_2018_01",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/a28cb2c0-8fb8-4330-8a81-c6fba16286c0?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/a28cb2c0-8fb8-4330-8a81-c6fba16286c0/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/basemap_medres_monthly_california_2018_04/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -124.628906,
#     32.249974,
#     -113.90625,
#     42.163403
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-04-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "a28cb2c0-8fb8-4330-8a81-c6fba16286c0",
#   "interval": "1 mon",
#   "item_types": [
#     "PSScene3Band",
#     "REOrthoTile"
#   ],
#   "last_acquired": "2018-05-01T00:00:00.000Z",
#   "level": 15,
#   "name": "basemap_medres_monthly_california_2018_04",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/09a8aff2-5ff6-4f9d-a393-7828e58abb99?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/09a8aff2-5ff6-4f9d-a393-7828e58abb99/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/basemap_medres_monthly_california_2018_05/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -124.628906,
#     32.249974,
#     -113.90625,
#     42.163403
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-05-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "09a8aff2-5ff6-4f9d-a393-7828e58abb99",
#   "interval": "1 mon",
#   "item_types": [
#     "PSScene3Band",
#     "REOrthoTile"
#   ],
#   "last_acquired": "2018-06-01T00:00:00.000Z",
#   "level": 15,
#   "name": "basemap_medres_monthly_california_2018_05",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/2287bb55-3ba4-421a-9748-637320c682de?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/2287bb55-3ba4-421a-9748-637320c682de/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/basemap_medres_monthly_california_2018_06/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -124.628906,
#     32.249974,
#     -113.90625,
#     42.163403
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-06-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "2287bb55-3ba4-421a-9748-637320c682de",
#   "interval": "1 mon",
#   "item_types": [
#     "PSScene3Band",
#     "REOrthoTile"
#   ],
#   "last_acquired": "2018-07-01T00:00:00.000Z",
#   "level": 15,
#   "name": "basemap_medres_monthly_california_2018_06",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/6eae4322-73db-41a8-b02e-a879ae35a26e?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/6eae4322-73db-41a8-b02e-a879ae35a26e/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/basemap_medres_monthly_california_2018_07/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -124.628906,
#     32.249974,
#     -113.90625,
#     42.163403
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-07-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "6eae4322-73db-41a8-b02e-a879ae35a26e",
#   "interval": "1 mon",
#   "item_types": [
#     "PSScene3Band",
#     "REOrthoTile"
#   ],
#   "last_acquired": "2018-08-01T00:00:00.000Z",
#   "level": 15,
#   "name": "basemap_medres_monthly_california_2018_07",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/e3230d47-37e1-453e-b12a-5c246987533e?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/e3230d47-37e1-453e-b12a-5c246987533e/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/basemap_medres_monthly_california_2018_08/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -124.628906,
#     32.249974,
#     -113.90625,
# ...
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-09-24T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "9e2bf15e-4574-477f-aeb5-f8e37e90fbcc",
#   "interval": "00:00:07",
#   "item_types": [
#     "PSScene3Band",
#     "REOrthoTile"
#   ],
#   "last_acquired": "2018-10-01T00:00:00.000Z",
#   "level": 15,
#   "name": "basemap_medres_weekly_eagle_ford_20180924_20181001",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/9e7f2bf6-c5b8-44a0-8209-d7bfc277e533?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/9e7f2bf6-c5b8-44a0-8209-d7bfc277e533/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/basemap_medres_weekly_eagle_ford_20181001_20181008/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -100.722656235955,
#     27.371767297061,
#     -96.50390623654,
#     30.448673675505
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-10-01T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "9e7f2bf6-c5b8-44a0-8209-d7bfc277e533",
#   "interval": "00:00:07",
#   "item_types": [
#     "PSScene3Band",
#     "REOrthoTile"
#   ],
#   "last_acquired": "2018-10-08T00:00:00.000Z",
#   "level": 15,
#   "name": "basemap_medres_weekly_eagle_ford_20181001_20181008",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/b46ae2e9-7c7c-4cf8-8176-6978cd9f5bf5?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/b46ae2e9-7c7c-4cf8-8176-6978cd9f5bf5/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/basemap_medres_weekly_eagle_ford_20181008_20181015/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -100.722656235955,
#     27.371767297061,
#     -96.50390623654,
#     30.448673675505
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-10-08T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "b46ae2e9-7c7c-4cf8-8176-6978cd9f5bf5",
#   "interval": "00:00:07",
#   "item_types": [
#     "PSScene3Band",
#     "REOrthoTile"
#   ],
#   "last_acquired": "2018-10-15T00:00:00.000Z",
#   "level": 15,
#   "name": "basemap_medres_weekly_eagle_ford_20181008_20181015",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/8928363d-f8b3-4b0b-8954-dac70121408c?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/8928363d-f8b3-4b0b-8954-dac70121408c/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/basemap_medres_weekly_eagle_ford_20181015_20181022/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -100.722656235955,
#     27.994401407517,
#     -96.50390623654,
#     30.297017879605
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-10-15T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "8928363d-f8b3-4b0b-8954-dac70121408c",
#   "interval": "00:00:07",
#   "item_types": [
#     "PSScene3Band",
#     "REOrthoTile"
#   ],
#   "last_acquired": "2018-10-22T00:00:00.000Z",
#   "level": 15,
#   "name": "basemap_medres_weekly_eagle_ford_20181015_20181022",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/fa2b0fe2-12e1-4514-93fd-55d0630813a9?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/fa2b0fe2-12e1-4514-93fd-55d0630813a9/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/basemap_medres_weekly_eagle_ford_20181022_20181029/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -100.722656235955,
#     27.371767297061,
#     -96.50390623654,
#     30.448673675505
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-10-22T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "fa2b0fe2-12e1-4514-93fd-55d0630813a9",
#   "interval": "00:00:07",
#   "item_types": [
#     "PSScene3Band",
#     "REOrthoTile"
#   ],
#   "last_acquired": "2018-10-29T00:00:00.000Z",
#   "level": 15,
#   "name": "basemap_medres_weekly_eagle_ford_20181022_20181029",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/250d2c16-9f34-455d-9659-3936a096793b?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/250d2c16-9f34-455d-9659-3936a096793b/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/basemap_medres_weekly_eagle_ford_20181029_20181105/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -100.722656235955,
#     27.371767297061,
#     -96.50390623654,
#     30.448673675505
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-10-29T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "250d2c16-9f34-455d-9659-3936a096793b",
#   "interval": "00:00:07",
#   "item_types": [
#     "PSScene3Band",
#     "REOrthoTile"
#   ],
#   "last_acquired": "2018-11-05T00:00:00.000Z",
#   "level": 15,
#   "name": "basemap_medres_weekly_eagle_ford_20181029_20181105",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/8888fd8e-5bce-42b6-a461-7344b1f05c77?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/8888fd8e-5bce-42b6-a461-7344b1f05c77/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/basemap_medres_weekly_eagle_ford_20181105_20181112/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -100.722656235955,
#     27.371767297061,
#     -96.50390623654,
#     30.448673675505
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-11-05T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "8888fd8e-5bce-42b6-a461-7344b1f05c77",
#   "interval": "00:00:07",
#   "item_types": [
#     "PSScene3Band",
#     "REOrthoTile"
#   ],
#   "last_acquired": "2018-11-12T00:00:00.000Z",
#   "level": 15,
#   "name": "basemap_medres_weekly_eagle_ford_20181105_20181112",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/1e27c343-4e2f-4247-9505-49a4ddc1f968?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/1e27c343-4e2f-4247-9505-49a4ddc1f968/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/basemap_medres_weekly_eagle_ford_20181112_20181119/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -100.722656235955,
#     27.371767297061,
#     -96.50390623654,
#     30.448673675505
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-11-12T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "1e27c343-4e2f-4247-9505-49a4ddc1f968",
#   "interval": "00:00:07",
#   "item_types": [
#     "PSScene3Band",
#     "REOrthoTile"
#   ],
#   "last_acquired": "2018-11-19T00:00:00.000Z",
#   "level": 15,
#   "name": "basemap_medres_weekly_eagle_ford_20181112_20181119",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/abf01aa1-009a-4e8e-bcba-cdccc5310591?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/abf01aa1-009a-4e8e-bcba-cdccc5310591/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/basemap_medres_weekly_eagle_ford_20181119_20181126/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -100.722656235955,
#     27.371767297061,
#     -96.50390623654,
#     30.448673675505
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-11-19T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "abf01aa1-009a-4e8e-bcba-cdccc5310591",
#   "interval": "00:00:07",
#   "item_types": [
#     "PSScene3Band",
#     "REOrthoTile"
#   ],
#   "last_acquired": "2018-11-26T00:00:00.000Z",
#   "level": 15,
#   "name": "basemap_medres_weekly_eagle_ford_20181119_20181126",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/e6411bda-e1f8-48eb-92d0-8dd72f2b2bbe?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/e6411bda-e1f8-48eb-92d0-8dd72f2b2bbe/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/basemap_medres_weekly_eagle_ford_20181126_20181203/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -100.722656235955,
#     27.371767297061,
#     -96.50390623654,
#     30.448673675505
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-11-26T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "e6411bda-e1f8-48eb-92d0-8dd72f2b2bbe",
#   "interval": "00:00:07",
#   "item_types": [
#     "PSScene3Band",
#     "REOrthoTile"
#   ],
#   "last_acquired": "2018-12-03T00:00:00.000Z",
#   "level": 15,
#   "name": "basemap_medres_weekly_eagle_ford_20181126_20181203",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/412a5cdd-4094-4dbd-9ced-4d938c92cd39?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/412a5cdd-4094-4dbd-9ced-4d938c92cd39/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/basemap_medres_weekly_eagle_ford_20181203_20181210/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -100.722656235955,
#     27.371767297061,
#     -96.50390623654,
#     30.448673675505
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-12-03T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "412a5cdd-4094-4dbd-9ced-4d938c92cd39",
#   "interval": "00:00:07",
#   "item_types": [
#     "PSScene3Band",
#     "REOrthoTile"
#   ],
#   "last_acquired": "2018-12-10T00:00:00.000Z",
#   "level": 15,
#   "name": "basemap_medres_weekly_eagle_ford_20181203_20181210",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/cb5f6b36-5dba-4652-810f-6f50490a42ab?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/cb5f6b36-5dba-4652-810f-6f50490a42ab/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/basemap_medres_weekly_eagle_ford_20181210_20181217/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -100.722656235955,
#     27.371767297061,
#     -96.50390623654,
#     30.448673675505
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-12-10T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "cb5f6b36-5dba-4652-810f-6f50490a42ab",
#   "interval": "00:00:07",
#   "item_types": [
#     "PSScene3Band",
#     "REOrthoTile"
#   ],
#   "last_acquired": "2018-12-17T00:00:00.000Z",
#   "level": 15,
#   "name": "basemap_medres_weekly_eagle_ford_20181210_20181217",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/676178e5-e721-4585-9003-97877b809515?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/676178e5-e721-4585-9003-97877b809515/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/basemap_medres_weekly_eagle_ford_20181217_20181224/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -100.722656235955,
#     27.371767297061,
#     -96.50390623654,
#     30.448673675505
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-12-17T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "676178e5-e721-4585-9003-97877b809515",
#   "interval": "00:00:07",
#   "item_types": [
#     "PSScene3Band",
#     "REOrthoTile"
#   ],
#   "last_acquired": "2018-12-24T00:00:00.000Z",
#   "level": 15,
#   "name": "basemap_medres_weekly_eagle_ford_20181217_20181224",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/c946e2a0-adb3-4d6a-a785-e5555b5a8d64?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/c946e2a0-adb3-4d6a-a785-e5555b5a8d64/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/basemap_medres_weekly_eagle_ford_20181224_20181231/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -100.722656235955,
#     27.371767297061,
#     -96.50390623654,
#     30.448673675505
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-12-24T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "c946e2a0-adb3-4d6a-a785-e5555b5a8d64",
#   "interval": "00:00:07",
#   "item_types": [
#     "PSScene3Band",
#     "REOrthoTile"
#   ],
#   "last_acquired": "2018-12-31T00:00:00.000Z",
#   "level": 15,
#   "name": "basemap_medres_weekly_eagle_ford_20181224_20181231",
#   "product_type": "timelapse",
#   "quad_download": true
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics/06204305-28a0-402e-a9f4-1bb4e01670a6?api_key=c56796734cf349749d32df718ffbcc57",
#     "quads": "https://api.planet.com/basemaps/v1/mosaics/06204305-28a0-402e-a9f4-1bb4e01670a6/quads?api_key=c56796734cf349749d32df718ffbcc57&bbox={lx},{ly},{ux},{uy}",
#     "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/basemap_medres_weekly_eagle_ford_20181231_20190107/gmap/{z}/{x}/{y}.png?api_key=c56796734cf349749d32df718ffbcc57"
#   },
#   "bbox": [
#     -100.722656235955,
#     27.371767297061,
#     -96.50390623654,
#     30.448673675505
#   ],
#   "coordinate_system": "EPSG:3857",
#   "datatype": "byte",
#   "first_acquired": "2018-12-31T00:00:00.000Z",
#   "grid": {
#     "quad_size": 4096,
#     "resolution": 4.777314267823516
#   },
#   "id": "06204305-28a0-402e-a9f4-1bb4e01670a6",
#   "interval": "00:00:07",
#   "item_types": [
#     "PSScene3Band",
#     "REOrthoTile"
#   ],
#   "last_acquired": "2019-01-07T00:00:00.000Z",
#   "level": 15,
#   "name": "basemap_medres_weekly_eagle_ford_20181231_20190107",
#   "product_type": "timelapse",
#   "quad_download": true
# }

# %%
dir(mosaics)
# Out:
# ['ITEM_KEY',
#  'LINKS_KEY',
#  'NEXT_KEY',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_cancel',
#  '_dispatcher',
#  '_json_stream',
#  '_pages',
#  '_request',
#  '_write',
#  'get',
#  'get_raw',
#  'items_iter',
#  'iter',
#  'json_encode',
#  'last_modified',
#  'name',
#  'next',
#  'response',
#  'size',
#  'write']

# %%
with open("basemap_search.json", 'w+') as fileout:
    mosaics.json_encode(fileout, indent=2)
